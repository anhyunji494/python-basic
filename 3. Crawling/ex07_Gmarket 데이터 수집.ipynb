# %% [markdown]
# ### 학습목표
# - Gmarket 페이지에서 상품명, 가격, 카테고리 수집
# ![image.png](attachment:image.png)

# %%
# 라이브러리 불러오기 
from selenium import webdriver as wb 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
# Gmarket 페이지 열기 
driver = wb.Chrome()
driver.get('https://www.gmarket.co.kr/n/best')

# %%
# 1. 1위 상품 클릭하여 페이지 이동
driver.find_element(By.CLASS_NAME,'image__lazy.image__load').click()

# %%
# 2. 상품명, 가격, 카테고리 데이터 수집
# title, price, cate 변수에 담기 
title = driver.find_element(By.CLASS_NAME,'itemtit').text
price = driver.find_element(By.CLASS_NAME,'price_real').text
cate = driver.find_element(By.CSS_SELECTOR,'li.on>a').text

# %% [markdown]
# ❗ 태그 선택 하는 방법
# - 절대적인 위치를 가져올 수 있음 => 페이지에서 한번만 사용 가능
# - 원하는 태그 위에서 우클릭 > copy > copy selector > 클립보드에 복사됨 > 코드창에 붙여넣기
# ex) #itemcase_basic > div.box__item-title > h1 => CSS_SELECTOR
#
# ![image.png](attachment:image.png)

# %%
# 2-1 절대경로 연습
# 상품명, 가격, 카테고리 데이터 수집
# title, price, cate 변수에 담기 
title = driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > h1').text
price = driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > div.price > span.price_innerwrap.price_innerwrap-coupon > strong').text
cate = driver.find_element(By.CSS_SELECTOR,'body > div.location-navi > ul > li.on > a').text

# %%
# 3. 출력 
print(title, price, cate, sep='\n')
# Out:
# (15%+5%쿠폰) 시크릿무드 역마진 단하루/ 겨울마감+봄맞이 BEST신상 데일리룩 가디건/니트/자켓/팬츠/스커트
# 8,000원
# 라운드넥티셔츠

# %%
# 뒤로가기 
driver.back()

# %% [markdown]
# ### 상위 10개 데이터 수집하기

# %%
# 코드 합치기
# 라이브러리 불러오기
from selenium import webdriver as wb # 통제,제어
from selenium.webdriver.common.keys import Keys # 입력, 컴퓨터용 키보드
from selenium.webdriver.common.by import By # 구분
import pandas as pd
import time #쉬는시간

# gmarket 페이지 열기
driver = wb.Chrome()
driver.get('http://corners.gmarket.co.kr/Bestsellers')
time.sleep(1)
#반복문
for i in range(10):
    # 이미지를 클릭
    driver.find_elements(By.CLASS_NAME,'image__lazy.image__load')[i].click()
    time.sleep(1)
    #상품명, 가격, 카테고리 정보를  절대적인 위치로 가져와보자!
    title = driver.find_element(By.CSS_SELECTOR, '#itemcase_basic > div.box__item-title > h1').text
    price = driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > div.price > span:nth-child(2) > strong').text
    cate =  driver.find_element(By.CSS_SELECTOR,'body > div.location-navi > ul > li.on > a').text
    print(title, price, cate, sep = '\n')
    # 뒤로가기
    driver.back()
    time.sleep(1)
# Out:
# 대한민국 대표 그림 동화 작가 - 백희나 그림책 - 골라담기 핫딜
# 6,600원
# 유아
# (15%+5%쿠폰) 시크릿무드 역마진 단하루/ 겨울마감+봄맞이 BEST신상 데일리룩 가디건/니트/자켓/팬츠/스커트
# 10,000원
# 라운드넥티셔츠
# LIVE체감가6만4천원 갤럭시 버즈2 무선 블루투스 이어폰 SM-R177 +신세계5천원+선물포장 증정 (G라이브)
# 94,090원
# 블루투스이어폰
# 삼성전자 갤럭시 워치6 블루투스 40mm 최대혜택가 187000 신세계 상품권 2만+보호필름+선물포장+2종혜택
# 287,880원
# 스마트워치
# (신세계타임스퀘어점패션관)신상 최저가 순면 기본 무지 반팔 티셔츠 3+1PACK PHD5TR3900
# 17,930원
# 기본/라운드/브이넥
# (유니버스클럽 전용 쿠폰적용가 5천원) 메가박스 일반예매권 2D-주중/주말
# 15,000원
# 메가박스
# 투게더 6종 3+2개 골라담기 +구매기프트 3개
# 29,200원
# 아이스크림
# 캡슐당 419원)일리 네스프레소 호환 커피 캡슐 6종 100캡슐 맛선택가능
# 55,900원
# 캡슐커피
# 닥터페퍼 제로 355ML 24입 1박스 탄산음료
# 21,900원
# 탄산/기능성음료
# (신세계본점)본점단독블루독베이비 경량패딩점퍼 60000원 (43A19-113-99)
# 45,000원
# 유아동점퍼

# %%
# 코드 합치기
# 라이브러리 불러오기
from selenium import webdriver as wb # 통제,제어
from selenium.webdriver.common.keys import Keys # 입력, 컴퓨터용 키보드
from selenium.webdriver.common.by import By # 구분
import pandas as pd
import time #쉬는시간

#반복 진행상황을 로딩바로 확인
from tqdm import tqdm

# gmarket 페이지 열기
driver = wb.Chrome()
driver.get('http://corners.gmarket.co.kr/Bestsellers')
time.sleep(1)
#반복문
for i in tqdm(range(10)):
    # 이미지를 클릭
    driver.find_elements(By.CLASS_NAME,'image__lazy.image__load')[i].click()
    time.sleep(1)
    #상품명, 가격, 카테고리 정보를  절대적인 위치로 가져와보자!
    title = driver.find_element(By.CSS_SELECTOR, '#itemcase_basic > div.box__item-title > h1').text
    price = driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > div.price > span:nth-child(2) > strong').text
    cate =  driver.find_element(By.CSS_SELECTOR,'body > div.location-navi > ul > li.on > a').text
    
    # 뒤로가기
    driver.back()
    time.sleep(1)
# Out:
# 100%|██████████| 10/10 [00:54<00:00,  5.44s/it]

# %%
# 코드 합치기
# 라이브러리 불러오기
from selenium import webdriver as wb # 통제,제어
from selenium.webdriver.common.keys import Keys # 입력, 컴퓨터용 키보드
from selenium.webdriver.common.by import By # 구분
import pandas as pd
import time #쉬는시간

#반복 진행상황을 로딩바로 확인
from tqdm import tqdm

# gmarket 페이지 열기
driver = wb.Chrome()
driver.get('http://corners.gmarket.co.kr/Bestsellers')
time.sleep(1)
#반복문
for i in tqdm(range(10)):
    # 이미지를 클릭
    driver.find_element(By.CSS_SELECTOR,f'#gBestWrap > div.best-list > ul > li:nth-child({i+1}) > div.thumb > a > img').click()
    time.sleep(1)
    #상품명, 가격, 카테고리 정보를  절대적인 위치로 가져와보자!
    title = driver.find_element(By.CSS_SELECTOR, '#itemcase_basic > div.box__item-title > h1').text
    price = driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > div.price > span:nth-child(2) > strong').text
    cate =  driver.find_element(By.CSS_SELECTOR,'body > div.location-navi > ul > li.on > a').text
    print(title, price, cate, sep = '\n')
    
    # 뒤로가기
    driver.back()
    time.sleep(1)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 대한민국 대표 그림 동화 작가 - 백희나 그림책 - 골라담기 핫딜
# 6,600원
# 유아
#  25%|██▌       | 1/4 [00:04<00:14,  5.00s/it]
# (15%+5%쿠폰) 시크릿무드 역마진 단하루/ 겨울마감+봄맞이 BEST신상 데일리룩 가디건/니트/자켓/팬츠/스커트
# 10,000원
# 라운드넥티셔츠
#  50%|█████     | 2/4 [00:10<00:10,  5.44s/it]
# LIVE체감가6만4천원 갤럭시 버즈2 무선 블루투스 이어폰 SM-R177 +신세계5천원+선물포장 증정 (G라이브)
# 94,090원
# 블루투스이어폰
#  75%|███████▌  | 3/4 [00:16<00:05,  5.39s/it]
# 삼성전자 갤럭시 워치6 블루투스 40mm 최대혜택가 187000 신세계 상품권 2만+보호필름+선물포장+2종혜택
# 287,880원
# 스마트워치
# 100%|██████████| 4/4 [00:21<00:00,  5.42s/it]
