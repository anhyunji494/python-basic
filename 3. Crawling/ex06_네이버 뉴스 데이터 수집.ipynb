# %% [markdown]
# ### 네이버 메인 페이지에서 > 키워드 검색 > 뉴스탭 선택 > 뉴스 제목

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from selenium import webdriver as wb 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd 
driver = wb.Chrome()
driver.get('https://www.naver.com/')
search = driver.find_element(By.ID,'query')
search.send_keys('라이즈 원빈')
search.send_keys(Keys.ENTER)
btn = driver.find_element(By.ID,'search-btn')
btn.click()
btn_news = driver.find_element(By.CLASS_NAME,'tab')

# %%
from selenium import webdriver as wb 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd 
from bs4 import BeautifulSoup as bs
driver = wb.Chrome()
driver.get('https://www.naver.com/')
search = driver.find_element(By.ID,'query')
keyword = input('키워드를 입력하세요 >>')
search.send_keys(keyword)
search.send_keys(Keys.ENTER)
btn_news = driver.find_element(By.CSS_SELECTOR,'div.api_flicking_wrap._conveyer_root>div:nth-child(8)')
# 여러개의 이름이 같은 태그일 때 (형제가 많을 때) 특정 순서의 데이터만 선택 
# 태그명:nth-child(순서)
btn_news.click()
headline = driver.find_elements(By.CLASS_NAME,'news_tit')
for i in headline : 
    print(i.text)
import time 
headline_list = []
for i in range(len(headline)):
    headline_list.append(headline[i].text)
    time.sleep(1)
dic = {'뉴스제목':headline_list}
wonbin = pd.DataFrame(dic)
wonbin
# Out:
# 요즘 원빈은 라이즈 원빈…차은우 제치고 아이돌 개인 브랜드평판 1위
# [사진]라이즈 원빈,'진정한 만찢남'
# 라이즈 원빈 1위, 아이돌 개인 브랜드평판 정상 차지..2위 차은우·3위 태연
# 라이즈 대세로 라이즈…간발의 차로 세븐틴 꺾었다
# 라이즈 원빈 ‘만찢남 비주얼’[포토엔HD]
# 라이즈 원빈·앤톤 사이 차은우…비주얼 3대장 브랜드평판 톱3
# 2월 보이그룹 개인 브랜드 평판 1위는 라이즈 원빈...2위 아스트로 차은우 3위...
# 라이즈 원빈, 숨만 쉬어도 그림...'자꾸만 시선을 뺏겨' [mhn앨범]
# 1위 라이즈·2위 TWS·3위 보이넥스트도어, 4세대 남자 아이돌 그룹 트렌드지...
# 1위 라이즈·2위 TWS·3위 보이넥스트도어, 2024년 2월 3주차 4세대 남자 아이...
#                                                 뉴스제목
# 0              요즘 원빈은 라이즈 원빈…차은우 제치고 아이돌 개인 브랜드평판 1위
# 1                               [사진]라이즈 원빈,'진정한 만찢남'
# 2        라이즈 원빈 1위, 아이돌 개인 브랜드평판 정상 차지..2위 차은우·3위 태연
# 3                         라이즈 대세로 라이즈…간발의 차로 세븐틴 꺾었다
# 4                            라이즈 원빈 ‘만찢남 비주얼’[포토엔HD]
# 5                  라이즈 원빈·앤톤 사이 차은우…비주얼 3대장 브랜드평판 톱3
# 6   2월 보이그룹 개인 브랜드 평판 1위는 라이즈 원빈...2위 아스트로 차은우 3위...
# 7           라이즈 원빈, 숨만 쉬어도 그림...'자꾸만 시선을 뺏겨' [mhn앨범]
# 8    1위 라이즈·2위 TWS·3위 보이넥스트도어, 4세대 남자 아이돌 그룹 트렌드지...
# ...

# %%
# 탭의 순서가 바뀌게 되었을 경우에는 다른 탭을 선택 
# 써있는 텍스트를 통해서 클릭 
drive.find_element(By.LINK_TEXT,'뉴스')
